# %%
if "google.colab" in str(get_ipython()):
	from google.colab import userdata
	access_token = userdata.get('CASM-GLOBAL')
	# !pip install git+https://{access_token}@github.com/CASM-Consulting/emif-pk.git@contrastive-experiment
# Out:
# ...
#   Cloning https://****@github.com/CASM-Consulting/emif-pk.git (to revision contrastive-experiment) to /tmp/pip-req-build-05mw4206
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/CASM-Consulting/emif-pk.git' /tmp/pip-req-build-05mw4206
#   Running command git checkout -b contrastive-experiment --track origin/contrastive-experiment
#   Switched to a new branch 'contrastive-experiment'
#   Branch 'contrastive-experiment' set up to track remote branch 'contrastive-experiment' from 'origin'.
#   Resolved https://****@github.com/CASM-Consulting/emif-pk.git to commit 37fc7acf7eb16e105a20c5253cae641680cfd8ea
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 25.4 MB/s eta 0:00:00
# ...

# %%
import logging
from contrastive_experiment.utils import get_base_folder
from contrastive_experiment.workflows import EmbeddingExtractionWorkflow
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# # Contrastive

# %%
TEXT_COL = 'preprocessedV2Text'
MODEL_NAME = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'
base_folder = get_base_folder()
model_dir = base_folder / 'contrastive-experiment/models/paraphrase_multilingual_mpnet'
# base_line_dir = model_dir / 'baseline'
experiment_dir = model_dir / 'contrastive_fixed'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### stratified

# %%
search_params = {
    'loss': 'contrastive',
    'model_name': 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
    'num_train_epochs': 1,
    'per_device_train_batch_size': 32,
    'per_device_eval_batch_size': 32,
    'run_name': 'contrastive_fixed-stratified-25k'

}

workflow = EmbeddingExtractionWorkflow(base_folder, experiment_dir, search_params, text_col=TEXT_COL, model_name=MODEL_NAME)
workflow.run()
# Out:
# INFO:root:Reading data...
# 2024-07-12 14:25:32,709 - root - INFO - Reading data...
# INFO:root:Baseline extraction is skipped
# 2024-07-12 14:25:46,773 - root - INFO - Baseline extraction is skipped
# INFO:root:Experiment extraction ...
# 2024-07-12 14:25:46,775 - root - INFO - Experiment extraction ...
# INFO:root:Searching for configurations...
# 2024-07-12 14:25:46,779 - root - INFO - Searching for configurations...
# ...

# %%
search_params = {
    'loss': 'contrastive',
    'model_name': 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
    'num_train_epochs': 1,
    'per_device_train_batch_size': 32,
    'per_device_eval_batch_size': 32,
    'run_name': 'contrastive_fixed-stratified-50k'

}

workflow = EmbeddingExtractionWorkflow(base_folder, base_line_dir, experiment_dir, search_params, text_col=TEXT_COL, model_name=MODEL_NAME)
workflow.run()

# %% [markdown]
# ### default

# %%
search_params = {
    'loss': 'contrastive',
    'model_name': 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
    'num_train_epochs': 1,
    'per_device_train_batch_size': 32,
    'per_device_eval_batch_size': 32,
    'run_name': 'contrastive_fixed-default-10'

}

workflow = EmbeddingExtractionWorkflow(base_folder, experiment_dir, search_params, text_col=TEXT_COL, model_name=MODEL_NAME)
workflow.run()
# Out:
# INFO:root:Reading data...
# 2024-07-12 05:21:05,850 - root - INFO - Reading data...
# 2024-07-12 05:21:05,850 - root - INFO - Reading data...
# INFO:root:Baseline extraction is skipped
# 2024-07-12 05:21:19,386 - root - INFO - Baseline extraction is skipped
# 2024-07-12 05:21:19,386 - root - INFO - Baseline extraction is skipped
# INFO:root:Experiment extraction ...
# 2024-07-12 05:21:19,389 - root - INFO - Experiment extraction ...
# 2024-07-12 05:21:19,389 - root - INFO - Experiment extraction ...
# INFO:root:Searching for configurations...
# 2024-07-12 05:21:19,391 - root - INFO - Searching for configurations...
# 2024-07-12 05:21:19,391 - root - INFO - Searching for configurations...
# ...

# %% [markdown]
# # positive

# %%
TEXT_COL = 'preprocessedV2Text'
MODEL_NAME = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'
base_folder = get_base_folder()
model_dir = base_folder / 'contrastive-experiment/models/paraphrase_multilingual_mpnet'
base_line_dir = model_dir / 'baseline'
experiment_dir = model_dir / 'positive_fixed'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
search_params = {
    'loss': 'contrastive',
    'model_name': 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
    'num_train_epochs': 1,
    'per_device_train_batch_size': 32,
    'per_device_eval_batch_size': 32,
    'run_name': 'positive_fixed-default-10'

}

workflow = EmbeddingExtractionWorkflow(base_folder, base_line_dir, experiment_dir, search_params, text_col=TEXT_COL, model_name=MODEL_NAME)
workflow.run()
# Out:
# INFO:root:Reading data...
# 2024-07-09 11:52:35,883 - root - INFO - Reading data...
# 2024-07-09 11:52:35,883 - root - INFO - Reading data...
# INFO:root:Baseline extraction ...
# 2024-07-09 11:52:54,937 - root - INFO - Baseline extraction ...
# 2024-07-09 11:52:54,937 - root - INFO - Baseline extraction ...
# INFO:root:Generating baseline embeddings...
# 2024-07-09 11:52:54,939 - root - INFO - Generating baseline embeddings...
# 2024-07-09 11:52:54,939 - root - INFO - Generating baseline embeddings...
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# 2024-07-09 11:52:54,987 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: cuda
# 2024-07-09 11:52:54,987 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# ...

# %%
search_params = {
    'loss': 'contrastive',
    'model_name': 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
    'num_train_epochs': 1,
    'per_device_train_batch_size': 32,
    'per_device_eval_batch_size': 32,
    'run_name': 'positive_fixed-default-20'

}

workflow = EmbeddingExtractionWorkflow(base_folder, base_line_dir, experiment_dir, search_params, text_col=TEXT_COL, model_name=MODEL_NAME)
workflow.run()
# Out:
# INFO:root:Reading data...
# 2024-07-09 12:14:00,789 - root - INFO - Reading data...
# 2024-07-09 12:14:00,789 - root - INFO - Reading data...
# INFO:root:Baseline extraction ...
# 2024-07-09 12:14:02,393 - root - INFO - Baseline extraction ...
# 2024-07-09 12:14:02,393 - root - INFO - Baseline extraction ...
# INFO:root:Generating baseline embeddings...
# 2024-07-09 12:14:02,396 - root - INFO - Generating baseline embeddings...
# 2024-07-09 12:14:02,396 - root - INFO - Generating baseline embeddings...
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# 2024-07-09 12:14:02,402 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: cuda
# 2024-07-09 12:14:02,402 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# ...

# %%
search_params = {
    'loss': 'contrastive',
    'model_name': 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
    'num_train_epochs': 1,
    'per_device_train_batch_size': 32,
    'per_device_eval_batch_size': 32,
    'run_name': 'positive_fixed-stratified-10'

}

workflow = EmbeddingExtractionWorkflow(base_folder, base_line_dir, experiment_dir, search_params, text_col=TEXT_COL, model_name=MODEL_NAME)
workflow.run()
# Out:
# INFO:root:Reading data...
# 2024-07-09 13:45:41,287 - root - INFO - Reading data...
# 2024-07-09 13:45:41,287 - root - INFO - Reading data...
# INFO:root:Baseline extraction ...
# 2024-07-09 13:45:55,581 - root - INFO - Baseline extraction ...
# 2024-07-09 13:45:55,581 - root - INFO - Baseline extraction ...
# INFO:root:Generating baseline embeddings...
# 2024-07-09 13:45:55,584 - root - INFO - Generating baseline embeddings...
# 2024-07-09 13:45:55,584 - root - INFO - Generating baseline embeddings...
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# 2024-07-09 13:45:55,588 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: cuda
# 2024-07-09 13:45:55,588 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# ...

# %%
search_params = {
    'loss': 'contrastive',
    'model_name': 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
    'num_train_epochs': 1,
    'per_device_train_batch_size': 32,
    'per_device_eval_batch_size': 32,
    'run_name': 'positive_fixed-stratified-20'
}

workflow = EmbeddingExtractionWorkflow(base_folder, base_line_dir, experiment_dir, search_params, text_col=TEXT_COL, model_name=MODEL_NAME)
workflow.run()
# Out:
# INFO:root:Reading data...
# 2024-07-09 14:06:49,416 - root - INFO - Reading data...
# 2024-07-09 14:06:49,416 - root - INFO - Reading data...
# INFO:root:Baseline extraction ...
# 2024-07-09 14:06:51,001 - root - INFO - Baseline extraction ...
# 2024-07-09 14:06:51,001 - root - INFO - Baseline extraction ...
# INFO:root:Generating baseline embeddings...
# 2024-07-09 14:06:51,007 - root - INFO - Generating baseline embeddings...
# 2024-07-09 14:06:51,007 - root - INFO - Generating baseline embeddings...
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# 2024-07-09 14:06:51,010 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: cuda
# 2024-07-09 14:06:51,010 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# ...
