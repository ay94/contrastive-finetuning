# %%
if "google.colab" in str(get_ipython()):
	from google.colab import userdata
	access_token = userdata.get('CASM-GLOBAL')
	# !pip install git+https://{access_token}@github.com/CASM-Consulting/emif-pk.git@contrastive-experiment
# Out:
# ...
#   Cloning https://****@github.com/CASM-Consulting/emif-pk.git (to revision contrastive-experiment) to /tmp/pip-req-build-y_33vv59
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/CASM-Consulting/emif-pk.git' /tmp/pip-req-build-y_33vv59
#   Running command git checkout -b contrastive-experiment --track origin/contrastive-experiment
#   Switched to a new branch 'contrastive-experiment'
#   Branch 'contrastive-experiment' set up to track remote branch 'contrastive-experiment' from 'origin'.
#   Resolved https://****@github.com/CASM-Consulting/emif-pk.git to commit 7b6ba09e22b9e7467ffb5beb3edf893ace23dcee
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 12.0 MB/s eta 0:00:00
# ...

# %%
from contrastive_experiment.utils import get_base_folder, initialise_structure, add_experiment

# %%
base_folder = get_base_folder()
model_folder = base_folder / 'contrastive-experiment/paraphrase_multilingual_mpnet'
# initialising experiment structure
initialise_structure(model_folder, ['positive_fixed', 'contrastive_fixed'])
# adding another experiment or can add it with the code above by appending the list
# add_experiment(model_folder, 'contrastive_fixed')
# Out:
# Mounted at /content/drive
# Experiment structure created at: /content/drive/Shareddrives/EMIF Pro-Kremlin/IMF/contrastive-experiment/paraphrase_multilingual_mpnet
# Experiment added: /content/drive/Shareddrives/EMIF Pro-Kremlin/IMF/contrastive-experiment/paraphrase_multilingual_mpnet/contrastive_fixed
